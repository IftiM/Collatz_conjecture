# %% [markdown]
# '''
# From Wikipedia: The Collatz conjecture is a conjecture in mathematics that concerns sequences
# defined as follows: start with any positive integer n. Then each term is obtained from the previous
# term as follows: if the previous term is even, the next term is one half of the previous term.
# If the previous term is odd, the next term is 3 times the previous term plus 1.
#
# The conjecture is that no matter what value of n, the sequence will always reach 1.
# '''

# %%
# 3n+1
# Collatz Conjecture


i = int(input())
starting_number = i
# r is a counter, to calculate the number of steps needed to reach to number 1
r = 0

# Finding the max value the conjecture reached, initially used input value as maximum
max = i

while i != 1:
    r+=1
    print(f'Current step: {r}, current value {i}')
    if i % 2 == 0:
        i = int(i/2)
        if i > max:
            max = i
    else:
        i = int(3*i+1)
        if i > max:
            max = i

print(f'Starting number: {starting_number:,}')
print(f'Total number of steps = {r+1}')
print(f'Maximum value reached {max:,}')

# Try 41
# Out:
# 5
# Current step: 1, current value 5
# Current step: 2, current value 16
# Current step: 3, current value 8
# Current step: 4, current value 4
# Current step: 5, current value 2
# Starting number: 5
# Total number of steps = 6
# Maximum value reached 16

# %%
# Interesting observation: value 99,898,212 IS the largest value in that sequence.
# Had to change the coding, since it showed the wrong maximum amount.

# 99898212
# Starting number: 99,898,212
# Total number of steps = 201
# Maximum value reached 84,289,120

# Check the graph for Starting number: 122,321 at around 20th steps

# Check 62 and 63, same number of steps and same maximum number

# Check 98 + 25, how many 9,232 you get. Plus for 108, 109, 110: all has same number of steps and same maximum value

# %%
# 3n+1
# Collatz Conjecture
# Added matplolib graph for visualizing

import matplotlib.pyplot as plt

i = int(input())
starting_number = i
# r is a counter, to calculate the number of steps needed to reach to number 1
r = 0

# Finding the max value the conjecture reached,
# initially used input value as the maximum
max = i

x = []
y = []

while i != 1:
    r+=1
    x.append(r)
    y.append(i)
#     print(f'Current step: {r}, current value {i}')
    if i % 2 == 0:
        i = int(i/2)
        if i > max:
            max = i
    else:
        i = int(3*i+1)
        if i > max:
            max = i
    
x.append(r+1)
y.append(1)
plt.plot(x,y)
plt.show()

print(f'Starting number: {starting_number:,}')
print(f'Total number of steps = {r+1}')
print(f'Maximum value reached {max:,}')
# Out:
# 654456
# Starting number: 654,456
# Total number of steps = 186
# Maximum value reached 828,304

# %%
# 3n+1
# Collatz Conjecture
# Visualizing multiple (25) graphs

import matplotlib.pyplot as plt

i = int(input())
# q = int(input())
q = i + 25
starting_number = i
# r is a counter, to calculate the number of steps needed to reach to number 1
# r = 0

# Finding the max value the conjecture reached,
# initially used input value as the maximum




while starting_number < q:
    i = starting_number
    r = 0
    max = i
    x = []
    y = []
    while i != 1:
        r+=1
        x.append(r)
        y.append(i)
    #     print(f'Current step: {r}, current value {i}')
        if i % 2 == 0:
            i = int(i/2)
            if i > max:
                max = i
        else:
            i = int(3*i+1)
            if i > max:
                max = i

    x.append(r+1)
    y.append(1)
    plt.plot(x,y)


    print(f'Starting number: {starting_number:,}')
    print(f'Total number of steps = {r+1}')
    print(f'Maximum value reached {max:,}')
    starting_number += 1
    
plt.show()

# %%
# Reversing X axis, didn't worked as quite yet

# 3n+1
# Collatz Conjecture

import matplotlib.pyplot as plt

i = int(input())
# q = int(input())
q = i + 125
starting_number = i
# r is a counter, to calculate the number of steps needed to reach to number 1
# r = 0

# Finding the max value the conjecture reached,
# initially used input value as the maximum
max = i



while starting_number < q:
    i = starting_number
    r = 0
#     max = i
    x = []
    y = []
    while i != 1:
        r+=1
        x.append(r)
        y.append(i)
#         print(f'Current step: {r}, current value {i}')
        if i % 2 == 0:
            i = int(i/2)
            if i > max:
                max = i
                print(f'{max:,}')
        else:
            i = int(3*i+1)
            if i > max:
                max = i
                print(f'{max:,}')

    x.append(r+1)
    y.append(1)
#     y.reverse()
    plt.plot(x,y)
#     plt.gca().invert_xaxis()


#     print(f'Starting number: {starting_number:,}')
#     print(f'Total number of steps = {r+1}')
#     print(f'Maximum value reached {max:,}')
    starting_number += 1
    
print(f'{max:,}')
plt.show()
