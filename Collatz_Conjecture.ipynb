# %% [markdown]
# '''
# From Wikipedia: The Collatz conjecture is a conjecture in mathematics that concerns sequences
# defined as follows: start with any positive integer n. Then each term is obtained from the previous
# term as follows: if the previous term is even, the next term is one half of the previous term.
# If the previous term is odd, the next term is 3 times the previous term plus 1.
#
# The conjecture is that no matter what value of n, the sequence will always reach 1.
# '''

# %%
""" 3n+1 Collatz Conjecture
Start with any positive integer n
If the n even, divide by 2
If the n is odd, the next term is 3n+1 Keep going until it eventually reaches 1 """


i = int(input())
starting_number = i
# r is a counter, to calculate the number of steps needed to reach down to number 1
r = 0

# Finding the max value the conjecture reached, initially used input value as maximum
max = i

while i != 1:
    r+=1
    print(f'Current step: {r}, current value {i}')
    if i % 2 == 0:
        i = int(i/2)
        if i > max:
            max = i
    else:
        i = int(3*i+1)
        if i > max:
            max = i

print(f'Starting number: {starting_number:,}')
print(f'Total number of steps = {r+1}')
print(f'Maximum value reached {max:,}')

# Try 41
# Out:
# 10
# Current step: 1, current value 10
# Current step: 2, current value 5
# Current step: 3, current value 16
# Current step: 4, current value 8
# Current step: 5, current value 4
# Current step: 6, current value 2
# Starting number: 10
# Total number of steps = 7
# Maximum value reached 16

# %%
# 3n+1
# Collatz Conjecture
# Added matplolib graph for visualizing

import matplotlib.pyplot as plt

i = int(input())
starting_number = i
# r is a counter, to calculate the number of steps needed to reach to number 1
r = 0

# Finding the max value the conjecture reached,
# initially used input value as the maximum
max = i

x = []
y = []

while i != 1:
    r+=1
    x.append(r)
    y.append(i)
    if i % 2 == 0:
        i = int(i/2)
        if i > max:
            max = i
    else:
        i = int(3*i+1)
        if i > max:
            max = i
    
x.append(r+1)
y.append(1)
plt.plot(x,y)
plt.show()

print(f'Starting number: {starting_number:,}')
print(f'Total number of steps = {r+1}')
print(f'Maximum value reached {max:,}')
# Out:
# 554123
# Starting number: 554,123
# Total number of steps = 116
# Maximum value reached 2,843,584

# %%
# 3n+1
# Collatz Conjecture
# Visualizing multiple (25) graphs. Taking a single input from user, then creating 25 consecutive graphs.

import matplotlib.pyplot as plt

i = int(input())
# q = int(input())
q = i + 25
starting_number = i

while starting_number < q:
    i = starting_number
    r = 0
    max = i
    x = []
    y = []
    
    while i != 1:
        r+=1
        x.append(r)
        y.append(i)

        if i % 2 == 0:
            i = int(i/2)
            if i > max:
                max = i
        else:
            i = int(3*i+1)
            if i > max:
                max = i

    x.append(r+1)
    y.append(1)
    plt.plot(x,y)

    print(f'Starting number: {starting_number:,}')
    print(f'Total number of steps = {r+1}')
    print(f'Maximum value reached {max:,}')
    starting_number += 1
    
plt.show()
# Out:
# 77
# Starting number: 77
# Total number of steps = 23
# Maximum value reached 232
# Starting number: 78
# Total number of steps = 36
# Maximum value reached 304
# Starting number: 79
# Total number of steps = 36
# Maximum value reached 808
# Starting number: 80
# Total number of steps = 10
# Maximum value reached 80
# Starting number: 81
# Total number of steps = 23
# Maximum value reached 244
# Starting number: 82
# Total number of steps = 111
# Maximum value reached 9,232
# Starting number: 83
# Total number of steps = 111
# Maximum value reached 9,232
# Starting number: 84
# Total number of steps = 10
# Maximum value reached 84
# Starting number: 85
# Total number of steps = 10
# Maximum value reached 256
# Starting number: 86
# Total number of steps = 31
# Maximum value reached 196
# Starting number: 87
# Total number of steps = 31
# Maximum value reached 592
# Starting number: 88
# Total number of steps = 18
# Maximum value reached 88
# Starting number: 89
# Total number of steps = 31
# Maximum value reached 304
# Starting number: 90
# Total number of steps = 18
# Maximum value reached 136
# Starting number: 91
# Total number of steps = 93
# Maximum value reached 9,232
# Starting number: 92
# Total number of steps = 18
# Maximum value reached 160
# Starting number: 93
# Total number of steps = 18
# Maximum value reached 280
# Starting number: 94
# Total number of steps = 106
# Maximum value reached 9,232
# Starting number: 95
# Total number of steps = 106
# Maximum value reached 9,232
# Starting number: 96
# Total number of steps = 13
# Maximum value reached 96
# Starting number: 97
# Total number of steps = 119
# Maximum value reached 9,232
# Starting number: 98
# Total number of steps = 26
# Maximum value reached 148
# Starting number: 99
# Total number of steps = 26
# Maximum value reached 448
# Starting number: 100
# Total number of steps = 26
# Maximum value reached 100
# Starting number: 101
# Total number of steps = 26
# Maximum value reached 304

# %%
# Interesting observations: 

# value 99,898,212 IS the largest value in that sequence.
# Starting number: 99,898,212
# Total number of steps = 201
# Maximum value reached 84,289,120

# Check 62 and 63, same number of steps and same maximum number

# Check 98 + 25, how many 9,232 you get. Plus for 108, 109, 110: all has same number of steps and same maximum value
